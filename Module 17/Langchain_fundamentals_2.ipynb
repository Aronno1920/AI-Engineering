# %%
# !pip install langchain langchain-core langchain-community langgraph langchain_openai langchain-tavily

# %%
from langchain_core.tools import tool

@tool
def multiply(a: int, b: int) -> int:
   """Multiply two numbers."""
   return a * b

# %%
multiply.invoke({"a": 2, "b": 3})
# Out:
# 6

# %%
@tool
def add(a: int , b: int) -> int:
  """Add two numbers
    takes 2 parameters int  a , int b  and also returns int"""
  return a+b

# %%
add.invoke({"a": 2, "b": 3})
# Out:
# 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("/content/Mall_Customers.xls")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
@tool
def get_maximum_age(file_path: str) -> int:
   """Returns the maximum age from a DataFrame loaded from a CSV file.

   Args:
       file_path: The path to the CSV file.

   Returns:
       The maximum age in the DataFrame.
   """
   df = pd.read_csv(file_path)
   return df['Age'].max()

# %%
get_maximum_age.invoke({"file_path": "/content/Mall_Customers.xls"})
# Out:
# 70

# %%
df['Age'].max()
# Out:
# 70

# %%
# Import relevant functionality
from langchain.chat_models import init_chat_model
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import create_react_agent

# %%
import os
from langchain_openai import ChatOpenAI


# Remove this line, as it is unnecessary and may overwrite your valid token:
token = "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"
endpoint = "https://models.github.ai/inference"
model_name = "openai/gpt-4.1-mini"

if not token:
    raise ValueError("GITHUB_TOKEN environment variable not set. Please provide a valid token.")

llm =ChatOpenAI(
    model_name=model_name,
    openai_api_key=token,
    openai_api_base=endpoint,
    temperature=0.5,
)

# %%
# Create the agent
memory = MemorySaver()
model = llm
tools = [get_maximum_age,add,multiply]
agent_executor = create_react_agent(model, tools, checkpointer=memory)

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "Multiply 3 and 4",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 3 and 4
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_zhEvhJLwQQggYyiowzLTRMLO)
#  Call ID: call_zhEvhJLwQQggYyiowzLTRMLO
#   Args:
#     a: 3
#     b: 4
# ================================= Tool Message =================================
# Name: multiply
#
# 12
# ================================== Ai Message ==================================
#
# The result of multiplying 3 and 4 is 12.

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "Add 3 and 4  and 7",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Add 3 and 4  and 7
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_Q0WdEsoqsK9tXKv8CNKGbdTc)
#  Call ID: call_Q0WdEsoqsK9tXKv8CNKGbdTc
#   Args:
#     a: 3
#     b: 4
# ================================= Tool Message =================================
# Name: add
#
# 7
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_XgB2g4dPAD365RscwVkbkVLf)
#  Call ID: call_XgB2g4dPAD365RscwVkbkVLf
#   Args:
#     a: 7
#     b: 7
# ================================= Tool Message =================================
# Name: add
#
# 14
# ================================== Ai Message ==================================
#
# The sum of 3, 4, and 7 is 14.

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "what was my last message",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# what was my last message
# ================================== Ai Message ==================================
#
# Your last message was: "Add 3 and 4 and 7"

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "what was my first message",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# what was my first message
# ================================== Ai Message ==================================
#
# Your first message was: "Multiply 3 and 4"

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "get the maximum age from this file path /content/Mall_Customers.xls",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# get the maximum age from this file path /content/Mall_Customers.xls
# ================================== Ai Message ==================================
# Tool Calls:
#   get_maximum_age (call_m4WMfkQWUnshuN5FkfAjrUKp)
#  Call ID: call_m4WMfkQWUnshuN5FkfAjrUKp
#   Args:
#     file_path: /content/Mall_Customers.xls
# ================================= Tool Message =================================
# Name: get_maximum_age
#
# 70
# ================================== Ai Message ==================================
#
# The maximum age from the file at the path /content/Mall_Customers.xls is 70.

# %%
import getpass
import os
os.environ["TAVILY_API_KEY"] = "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"

# %%
from langchain_tavily import TavilySearch

tool = TavilySearch(
    max_results=5,
    topic="general",
)

# %%
tool.invoke({"query": "AI trending githubs"})
# Out:
# {'query': 'AI trending githubs',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://blog.stackademic.com/top-15-trending-github-repositories-for-ai-developement-ca05acb9d390',
#    'title': 'Top 15 Trending GitHub Repositories For AI Developement',
# ...

# %%
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}

input_message = {
    "role": "user",
    "content": "give me 4 add 5 , multiple by 2",
}
for step in agent_executor.stream(
    {"messages": [input_message]}, config, stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# give me 4 add 5 , multiple by 2
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_ivnd51kvr8Y43v07LbSNrRRQ)
#  Call ID: call_ivnd51kvr8Y43v07LbSNrRRQ
#   Args:
#     a: 4
#     b: 5
#   multiply (call_HbkTSJ1I0m9dtXODb79sjYQi)
#  Call ID: call_HbkTSJ1I0m9dtXODb79sjYQi
#   Args:
#     a: 9
#     b: 2
# ================================= Tool Message =================================
# Name: multiply
#
# 18
# ================================== Ai Message ==================================
#
# First, 4 added to 5 equals 9. Then, 9 multiplied by 2 equals 18. So, the final result is 18.

# %%
# multiagent communication
# handoff
# graudrails

# Langgraph
# Openai agent sdk
@tool
def weburl_data_fetch (url: str)
